# %%
#!pip install tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import time
import json
import sqlite3
conn = sqlite3.connect('twitter_db1')
c = conn.cursor()
c.execute('''
    CREATE TABLE if not exists taula_lang(
    time TEXT,
    username TEXT,
    tweet TEXT,
    language TEXT
    )
''')
conn.commit()

# %%
# In[23]:
#        replace mysql.server with "localhost" if you are running via your own server!
#                        server       MySQL username    MySQL pass  Database name.
#consumer key, consumer secret, access token, access secret.
ckey="TzwMspSvqZ4ewPJ1bSPApPSZZ"
csecret="prg3ETqTaMaIr5j2IgRmEXSh4NIeX1eAXQwMlb7G06wR2TK9sP"
atoken="1206716899616149504-tEgEkauzlhQAhZrX3BCVZNbxe6gquN"
asecret="JXRwt2JAsHuyIQ3tYm02Mqf34bgIW3yQuL8UBHRGdCSzn"
class listener(StreamListener):
    def __init__(self, time_limit=60):
        self.start_time = time.time()
        self.limit = time_limit
        self.saveFile = open('abcd.json', 'a')
        super(listener, self).__init__()
    def on_data(self, data):
        if (time.time() - self.start_time) < self.limit:
            all_data = json.loads(data)
    
            tweet = all_data["text"]
    
            username = all_data["user"]["screen_name"]
            language = all_data["lang"]
    
            c.execute("INSERT INTO taula_lang (time, username,language, tweet) VALUES (?,?,?,?)",
                (time.time(), username, language, tweet))
    
            conn.commit()
    
            print((username,tweet))
        
        return True
    def on_error(self, status):
        print (status)
        
auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)
twitterStream = Stream(auth, listener(time_limit=20))
twitterStream.filter(track=["basketball"])
# In[24]:
a=c.execute('''Select *  from  taula''')
print(a)
for i in a:
    print (i.lang)
# Out:
# ('Alden_Athletics', 'The varsity girls basketball team holds a 51-17 lead over the JFK Bears as the fourth quarter begins. https://t.co/wxBAXZz3Bq')
# ('Risda35642074', '🏀 High School Basketball Live Stream\nCSPA vs Rudolf Steiner\nGrosse Pointe South vs Dakota\nLakeview vs Portage North… https://t.co/SYp9dZip29')
# ('MorganDavii', 'RT @msmadshep: when i say “give me 5 minutes”... i mean 5 basketball minutes &amp; both teams still have all their timeouts')
# ('BubankusMoosaka', "@IcyWinslow @OMagicZone @orltragicstan @JJudahIsaac Its just an odd name to bring up. It's the kinda name you bring… https://t.co/OhheRkgxy2")
# ('tvsportsstream', '[~Live Stream~] Pepperdine Waves VS Portland State Vikings NCAA Basketball Watch\xa0Online https://t.co/HLdiywBLDz')
# ('JSWarno', '@JD_Jerbear @Sheehan_Sports Meh. Kids aren’t going to Duke because Dick Vitale yells about them on TV once or twice… https://t.co/oO2UDUWalG')
# ...
